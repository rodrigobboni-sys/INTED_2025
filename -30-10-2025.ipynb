# %% [markdown]
# <a href="https://colab.research.google.com/github/rodrigobboni-sys/INTED_2025/blob/main/-30-10-2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Peça um número e informe se ele é maior que 10
num1 = int(input("digite um número "))
if num1 > 10:
  print("ele é maior que 10")
else:
  print("ele é menor que 10")

# %%
#Peça um número inteiro e informe se ele é par
num1 = int(input("digite um número "))
if num1 % 2 == 0:
  print("ele é par")
else:
  print("ele é ímpar")
# Out:
# digite um número2
# ele é par

# %%
#Peça um nome e informe se ele contém a letra "a".
nome = input("digite um nome ")
if "a" or "A" in nome:
  print("tem a no nome")
else:
  print("não tem a no nome")
# Out:
# digite um nome Alisson
# tem a no nome

# %%
#Peça um número e informe se ele é múltiplo de 5
num1 = int(input("digite um número "))
if num1 % 5 == 0:
  print("ele é multiplo de 5")
else:
  print("ele não é multiplo de 5")
# Out:
# digite um número 7
# ele não é multiplo de 5

# %%
#Peça a temperatura atual e informe se está quente (acima de 30°C) ou frio (30°C ou menos)
num1 = int(input("Qual a temperatura atual"))
if num1 > 30:
  print("ta quente")
else:
  print("ta frio")

# %%
#Peça ao usuário para digitar "S" para continuar ou "N" para sair e informe a ação correspondente.
num1 = (input("Se quiser continuar, digite 'S'; Caso contrário, digite 'N' "))
if "S" in num1:
  print(" Você vai continuar")
elif "N" in num1:
   print(" Você vai sair")
else:
  print(" Digite 'S' ou 'N' idiota")
# Out:
# Se quiser continuar, digite S; Caso contrário, digite N s
#  Digite 'S' ou 'N'

# %%
#Peça um número e informe se ele é negativo, zero ou positivo
num1 = int(input("digite um número "))
if num1 > 0:
  print("ele é positivo")
elif num1 < 0:
  print("ele é negativo")
else:
  print("ele é zero")
# Out:
# digite um número0
# ele é zero

# %%
#Peça um número de 1 a 7 e informe o dia da semana correspondente.num1
num1 = int(input("digite um número "))
num1 = int(input("digite um número"))
if num1 == 1:
    print("Domingo")
elif num1 == 2:
    print("Segunda-feira")
elif num1 == 3:
    print("Terça-feira")
elif num1 == 4:
    print("Quarta-feira")
elif num1 == 5:
    print("Quinta-feira")
elif num1 == 6:
    print("Sexta-feira")
elif num1 == 7:
    print("Sábado")
else:
    print("Número inválido. Por favor, digite um número de 1 a 7.")
# Out:
# digite um número 5
# digite um número4
# Quarta-feira

# %%
#Peça um ano e informe se ele é bissexto
num1 = int(input("digite um ano: "))
if (num1 % 4 == 0 and num1 % 100 != 0) or (num1 % 400 == 0):
  print("é bissexto")
else:
  print("não é bissexto")
# Out:
# digite um ano: 2016
# é bissexto

# %%
#Peça a quantidade de horas trabalhadas e o valor por hora. Se trabalhou até 40 horas, calcule o salário normalmente (horas × valor por hora). Se trabalhou mais de 40 horas, as horas extras devem ter um adicional de 50% (horas extras × valor por hora × 1.5).
num1 = int(input("Quantas horas você trabalhou? "))
print (" ")
numh = int(input("Qual o valor você recebe por hora? "))
print (" ")

num2 = (num1 - 40)
num3 = ((40 * numh) + (num2 * (1.5 * numh)))

print(f"Você trabalhou {num2} horas extras")
print (" ")

if num1 <= 40:
  print (" ")
  print ("Você receberá")
  print (" ")
  print (num1 * numh)
else:
  print(f"Você receberá {num3} R$")
print (" ")
# Out:
# Quantas horas você trabalhou? 100
#
# Qual o valor por hora? 1
#
# Você trabalhou 60 horas extras
#
# Você receberá 130.0 R$
